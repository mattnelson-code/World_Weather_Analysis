# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=200)
lngs = np.random.uniform(low=-180.000, high=180.000, size=200)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list to hold the cities
cities = []

# Use citipy to identify the nearest city to each latitude and longitude.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Add each unique city to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the length of cities to confirm the sufficient count
len(cities)
# Out:
# 131

# %%
# URL for OpenWeatherMap API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0) & (i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Print the URL, record number, set number, and city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Increment record count.
    record_count += 1
    
    # Run an API request for each city.
    try:
        
        # Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["long"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"]["description"]
        
        # Append the data to the city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kahului
# City not found. Skipping...
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | victoria
# City not found. Skipping...
# Processing Record 4 of Set 1 | pochutla
# City not found. Skipping...
# Processing Record 5 of Set 1 | leningradskiy
# City not found. Skipping...
# Processing Record 6 of Set 1 | labuan
# City not found. Skipping...
# Processing Record 7 of Set 1 | luderitz
# City not found. Skipping...
# Processing Record 8 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 9 of Set 1 | airai
# City not found. Skipping...
# Processing Record 10 of Set 1 | sur
# City not found. Skipping...
# Processing Record 11 of Set 1 | albany
# City not found. Skipping...
# Processing Record 12 of Set 1 | mar del plata
# City not found. Skipping...
# Processing Record 13 of Set 1 | lata
# City not found. Skipping...
# Processing Record 14 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 15 of Set 1 | butaritari
# City not found. Skipping...
# Processing Record 16 of Set 1 | matara
# City not found. Skipping...
# Processing Record 17 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 18 of Set 1 | ponta do sol
# City not found. Skipping...
# Processing Record 19 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 20 of Set 1 | gat
# City not found. Skipping...
# Processing Record 21 of Set 1 | garbsen
# City not found. Skipping...
# Processing Record 22 of Set 1 | saint george
# City not found. Skipping...
# Processing Record 23 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 24 of Set 1 | saskylakh
# City not found. Skipping...
# Processing Record 25 of Set 1 | shaartuz
# City not found. Skipping...
# Processing Record 26 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 27 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 28 of Set 1 | upernavik
# City not found. Skipping...
# Processing Record 29 of Set 1 | carnarvon
# City not found. Skipping...
# Processing Record 30 of Set 1 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 31 of Set 1 | pontes e lacerda
# City not found. Skipping...
# Processing Record 32 of Set 1 | abu samrah
# City not found. Skipping...
# Processing Record 33 of Set 1 | snohomish
# City not found. Skipping...
# Processing Record 34 of Set 1 | marawi
# City not found. Skipping...
# Processing Record 35 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 36 of Set 1 | husavik
# City not found. Skipping...
# Processing Record 37 of Set 1 | zelenoborskiy
# City not found. Skipping...
# Processing Record 38 of Set 1 | sorokino
# Processing Record 42 of Set 2 | isangel
# City not found. Skipping...
# Processing Record 43 of Set 2 | vikulovo
# City not found. Skipping...
# Processing Record 44 of Set 2 | chokurdakh
# City not found. Skipping...
# Processing Record 45 of Set 2 | hailar
# City not found. Skipping...
# Processing Record 46 of Set 2 | japura
# City not found. Skipping...
# Processing Record 47 of Set 2 | komsomolskiy
# City not found. Skipping...
# Processing Record 48 of Set 2 | faya
# City not found. Skipping...
# Processing Record 49 of Set 2 | trebinje
# City not found. Skipping...
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | teguise
# City not found. Skipping...
# Processing Record 2 of Set 3 | hambantota
# City not found. Skipping...
# Processing Record 3 of Set 3 | port elizabeth
# City not found. Skipping...
# Processing Record 4 of Set 3 | sola
# City not found. Skipping...
# Processing Record 5 of Set 3 | yulara
# City not found. Skipping...
# Processing Record 6 of Set 3 | mahebourg
# City not found. Skipping...
# Processing Record 7 of Set 3 | yellowknife
# City not found. Skipping...
# Processing Record 8 of Set 3 | ballina
# City not found. Skipping...
# Processing Record 9 of Set 3 | saint-augustin
# City not found. Skipping...
# Processing Record 10 of Set 3 | avarua
# City not found. Skipping...
# Processing Record 11 of Set 3 | miraflores
# City not found. Skipping...
# Processing Record 12 of Set 3 | havelock
# City not found. Skipping...
# Processing Record 13 of Set 3 | codrington
# City not found. Skipping...
# Processing Record 14 of Set 3 | play cu
# City not found. Skipping...
# Processing Record 15 of Set 3 | georgetown
# City not found. Skipping...
# Processing Record 16 of Set 3 | saint-philippe
# City not found. Skipping...
# Processing Record 17 of Set 3 | ouahigouya
# City not found. Skipping...
# Processing Record 18 of Set 3 | ayan
# City not found. Skipping...
# Processing Record 19 of Set 3 | dikson
# City not found. Skipping...
# Processing Record 20 of Set 3 | nanga eboko
# City not found. Skipping...
# Processing Record 21 of Set 3 | chauk
# City not found. Skipping...
# Processing Record 22 of Set 3 | tura
# City not found. Skipping...
# Processing Record 23 of Set 3 | severnyy
# City not found. Skipping...
# Processing Record 24 of Set 3 | aswan
# City not found. Skipping...
# Processing Record 25 of Set 3 | bontang
# City not found. Skipping...
# Processing Record 26 of Set 3 | lexington park
# City not found. Skipping...
# Processing Record 27 of Set 3 | paraiso
# City not found. Skipping...
# Processing Record 28 of Set 3 | smithers
# City not found. Skipping...
# Processing Record 29 of Set 3 | atuona
# City not found. Skipping...
# Processing Record 30 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 3 | barrow
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a Pandas DataFrame to hold the array of dictionaries. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create the output file. 
csv_file = "Weather_Database/WeatherPy_Database.csv"

# Export city_data_df to a CSV file
city_data_df.to_csv(csv_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-feffa711d43b> in <module>
#       3
#       4 # Export city_data_df to a CSV file
# ----> 5 city_data_df.to_csv(csv_file, index_label="City_ID")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 errors = "replace"
#     646             # Encoding
# --> 647             handle = open(
#     648                 handle,
#     649                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
